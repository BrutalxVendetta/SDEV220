# %%
import pandas as pd
pd.__versioin__
csv_path = r"C:\Users\nguts\Downloads\telco_churn.csv"

df = pd.read_csv('telco_churn.csv')

df.head()

df.shape

df.info()

df.describe(numberic_only=True)

df.columns

df[df.columns[0]].head()

df[df.columns[:3]].head()

df.iloc[
