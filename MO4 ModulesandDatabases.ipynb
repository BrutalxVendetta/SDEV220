# %%
#11.1

# %%writefile zoo.py
def hours():
    print("Open 9-5 Daily")
# Out:
# Overwriting zoo.py

# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 Daily

# %%
11.2
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 Daily

# %%
#16.4
import sqlite3

conn = sqlite3.connect('books.db')

cursor = conn.cursor()

cursor.execute("""CREATE TABLE books ( title text, author text, year interger)""")

conn.commit()

conn.close()

print("Database and Table Created Sucsessfully")
# Out:
# Database and Table Created Sucsessfully

# %%
## First, make sure the Book table exists
# Option 1: Create the table if it doesn't exist
with engine.connect() as conn:
    # Create the Book table if it doesn't exist
    conn.execute("""
    CREATE TABLE IF NOT EXISTS Book (
        Title TEXT,
        # Add other columns as needed
    )
    """)
    
    # Then run your query
    results = conn.execute("Select Title From Book Order By Title ASC")
    for row in results:
        print(row[0])

# Option 2: If the table has a different name, use the correct table name
# with engine.connect() as conn:
#     results = conn.execute("Select Title From correct_table_name Order By Title ASC")
#     for row in results:
#         print(row[0])

# %%
#16.8
from sqlalchemy import create_engine, text
engine = create_engine('sqlite:///books.db')

# %%
query = text("Select Title From Book Order By Title ASC")

# %%
with engine.connect() as conn:
    results = conn.execute(query)
    for row in results:
        print(row[0])
