# %%
#13.1

from datetime import date

# Get Today's Date
today = date.today()

# Write the date as a string to the file
with open("Today.txt", "w") as file:
    file.write(str(today))

# %%
#13.2

# Read the date string from the file
with open("Today.txt", "r") as file:
    today_string = file.read()

print(today_string)
# Out:
# 2025-12-07

# %%
#13.3

from datetime import datetime

#Convert string back into a date object
parsed_date = datetime.strptime(today_string, "%Y-%m-%d").date()

print(parsed_date)
# Out:
# 2025-12-07

# %%
#15.1

from multiprocessing import Process
from datetime import datetime
import time
import random

def worker(name):
    #wait a random time between 0 and 1 seconds
    delay=random.uniform(0,1)
    time.sleep(delay)
    #Print which process and the current time
    print(f"Process {name} | Slept: {delay:.3f}s | Time: {datetime.now()}")
if __name__== "__main__":
    processes = []

    #create 3 separate processes
    for i in range(3):
        p = Proecess(target=worker, args=(i+1,))
        processes.append(p)
        p.start()
    #Wait for all of them to finish
    for p in processes:
        p.join()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 19
#      17 #create 3 separate processes
#      18 for i in range(3):
# ---> 19     p = Proecess(target=worker, args=(i+1,))
#      20     processes.append(p)
#      21     p.start()
#
# NameError: name 'Proecess' is not defined
